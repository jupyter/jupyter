# %% [markdown]
# # Data Analysis Template
#
# **Author:** Your Name
#
# **Date:** YYYY-MM-DD
#
# **Dataset:** Dataset name and source
#
# **Objective:** Describe the analysis objective
#
# ---

# %% [markdown]
# ## 1. Environment Setup

# %%
# Data manipulation and analysis
import numpy as np
import pandas as pd

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Set visualization style
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette('husl')

# Display settings
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)
pd.set_option('display.precision', 3)

# Matplotlib settings
# %matplotlib inline
plt.rcParams['figure.figsize'] = (12, 6)
plt.rcParams['font.size'] = 12

# %% [markdown]
# ## 2. Data Loading
#
# Load the dataset and perform initial inspection.

# %%
# Load data
# df = pd.read_csv('data/your_dataset.csv')
# df.head()

# %% [markdown]
# ## 3. Data Exploration
#
# Explore the structure and characteristics of the dataset.

# %%
# Dataset information
# print("Dataset shape:", df.shape)
# print("\nColumn types:")
# print(df.dtypes)
# print("\nBasic statistics:")
# df.describe()

# %%
# Check for missing values
# missing_data = df.isnull().sum()
# missing_percent = 100 * missing_data / len(df)
# missing_table = pd.concat([missing_data, missing_percent], axis=1, 
#                           keys=['Missing Values', 'Percent'])
# print(missing_table[missing_table['Missing Values'] > 0].sort_values('Percent', ascending=False))

# %% [markdown]
# ## 4. Data Cleaning
#
# Clean and preprocess the data.

# %%
# Handle missing values
# df_clean = df.copy()
# df_clean.dropna(subset=['important_column'], inplace=True)
# df_clean.fillna(df_clean.mean(), inplace=True)

# %%
# Remove duplicates
# df_clean.drop_duplicates(inplace=True)
# print(f"Removed {len(df) - len(df_clean)} duplicate rows")

# %% [markdown]
# ## 5. Exploratory Data Analysis (EDA)
#
# Visualize and analyze the data.

# %%
# Distribution plots
# fig, axes = plt.subplots(2, 2, figsize=(15, 10))
# df_clean['column1'].hist(ax=axes[0, 0], bins=30)
# axes[0, 0].set_title('Distribution of Column 1')
# plt.tight_layout()
# plt.show()

# %%
# Correlation matrix
# plt.figure(figsize=(12, 10))
# correlation_matrix = df_clean.corr()
# sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0)
# plt.title('Correlation Matrix')
# plt.show()

# %% [markdown]
# ## 6. Statistical Analysis
#
# Perform statistical tests and analysis.

# %%
# Groupby analysis
# grouped = df_clean.groupby('category_column').agg({
#     'numeric_column': ['mean', 'std', 'count']
# })
# print(grouped)

# %% [markdown]
# ## 7. Key Findings
#
# Summarize the main insights from the analysis.

# %% [markdown]
# ### Summary of Findings
#
# 1. **Finding 1:** Description
# 2. **Finding 2:** Description
# 3. **Finding 3:** Description
#
# ### Recommendations
#
# - Recommendation 1
# - Recommendation 2
# - Recommendation 3
#
# ### Next Steps
#
# - [ ] Further analysis needed
# - [ ] Additional data collection
# - [ ] Model development

# %% [markdown]
# ## 8. Export Results
#
# Save processed data and visualizations.

# %%
# Save cleaned data
# df_clean.to_csv('output/cleaned_data.csv', index=False)
# print("Data saved successfully")
